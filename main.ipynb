# %% [markdown]
# ## Import the Important Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import the dataset and put it into a dataframe

# %%
df = pd.read_csv("sets.csv")

# %% [markdown]
# ## Get the head and the tail of the dataframe

# %%
df.head()
# Out:
#   set_num                        name    year  theme_id  num_parts
# 0     NaN                   something     NaN       NaN        NaN
# 1    00-1             Weetabix Castle  1970.0     414.0      471.0
# 2    00-1             Weetabix Castle  1970.0     414.0      471.0
# 3  0011-2           Town Mini-Figures  1978.0      84.0       12.0
# 4  0011-3  Castle 2 for 1 Bonus Offer  1987.0     199.0        2.0

# %%
df.tail()
# Out:
#              set_num                                               name  \
# 11670    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11671   WHITEHOUSE-1                                  Micro White House
# 11672    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11673  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11674        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 11670  2012.0     408.0       15.0
# 11671  2015.0     598.0       59.0
# 11672  2010.0     408.0      146.0
# 11673  2013.0     494.0       28.0
# 11674  1996.0     476.0        3.0

# %% [markdown]
# ## Get the information of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11675 entries, 0 to 11674
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   set_num    11674 non-null  object
#  1   name       11675 non-null  object
#  2   year       11674 non-null  float64
#  3   theme_id   11674 non-null  float64
#  4   num_parts  11674 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 456.2+ KB

# %% [markdown]
# ## Get the basic statstics of the dataframe

# %%
df.describe()
# Out:
#                year      theme_id     num_parts
# count  11674.000000  11674.000000  11674.000000
# mean    2001.970019    311.317372    162.288847
# std       13.478036    177.994014    330.190329
# min     1950.000000      1.000000     -1.000000
# 25%     1997.000000    161.000000     10.000000
# 50%     2005.000000    324.000000     45.000000
# 75%     2012.000000    470.000000    172.000000
# max     2017.000000    614.000000   5922.000000

# %% [markdown]
# ## Check the null values in the data frame and remove it

# %%
df.isnull().sum()
# Out:
# set_num      1
# name         0
# year         1
# theme_id     1
# num_parts    1
# dtype: int64

# %%
df.dropna()
# Out:
#              set_num                                               name  \
# 1               00-1                                    Weetabix Castle
# 2               00-1                                    Weetabix Castle
# 3             0011-2                                  Town Mini-Figures
# 4             0011-3                         Castle 2 for 1 Bonus Offer
# 5             0012-1                                 Space Mini-Figures
# ...              ...                                                ...
# 11670    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11671   WHITEHOUSE-1                                  Micro White House
# 11672    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11673  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11674        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 1      1970.0     414.0      471.0
# ...

# %% [markdown]
# ## Check the duplicated values in the dataset and remove it

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#              set_num                                               name  \
# 0                NaN                                          something
# 1               00-1                                    Weetabix Castle
# 3             0011-2                                  Town Mini-Figures
# 4             0011-3                         Castle 2 for 1 Bonus Offer
# 5             0012-1                                 Space Mini-Figures
# ...              ...                                                ...
# 11670    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11671   WHITEHOUSE-1                                  Micro White House
# 11672    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11673  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11674        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 0         NaN       NaN        NaN
# ...

# %% [markdown]
# ## Fill the null values with 0

# %%
df.fillna(0)
# Out:
#              set_num                                               name  \
# 0                  0                                          something
# 1               00-1                                    Weetabix Castle
# 2               00-1                                    Weetabix Castle
# 3             0011-2                                  Town Mini-Figures
# 4             0011-3                         Castle 2 for 1 Bonus Offer
# ...              ...                                                ...
# 11670    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11671   WHITEHOUSE-1                                  Micro White House
# 11672    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11673  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11674        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 0         0.0       0.0        0.0
# ...

# %% [markdown]
# ## Visualize the destribution of the data

# %%
df.boxplot()
plt.show()

# %% [markdown]
# ## Save the cleaned data in a new csv file

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#              set_num                                               name  \
# 1               00-1                                    Weetabix Castle
# 3             0011-2                                  Town Mini-Figures
# 4             0011-3                         Castle 2 for 1 Bonus Offer
# 5             0012-1                                 Space Mini-Figures
# 6             0013-1                                 Space Mini-Figures
# ...              ...                                                ...
# 11670    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...
# 11671   WHITEHOUSE-1                                  Micro White House
# 11672    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...
# 11673  WishingWell-1                     Wishing Well [Toys R Us Promo]
# 11674        wwgp1-1                Wild West Limited Edition Gift Pack
#
#          year  theme_id  num_parts
# 1      1970.0     414.0      471.0
# ...

# %%
df = df.to_csv("sets (1).csv")
